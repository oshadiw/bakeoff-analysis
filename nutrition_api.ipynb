# %%
# import dependencies
import requests
import json
import numpy as np
import pandas as pd

# import api key from config
api_key = 'DEMO_KEY'

# %%
# make a call
requested_url = 'https://api.nal.usda.gov/fdc/v1/search?api_key='

headers = {'Content-Type': 'application/json'}

item = 'butter'

# pull item in list
data = {"generalSearchInput": 'butter'}
# convert to json format
data_str = json.dumps(data).encode("utf-8")

# make call
response = requests.get(f'{requested_url}{api_key}&query={item}&dataType=Foundation')

parsed = json.loads(response.content)

# %%
fdcId = parsed['foods'][0]['fdcId']
fdcId
# Out:
# 790508

# %%
# make a call
requested_nutr_url = f'https://api.nal.usda.gov/fdc/v1/food/{fdcId}?api_key='


# make call
response = requests.get(f'https://api.nal.usda.gov/fdc/v1/food/{fdcId}?api_key=DEMO_KEY&nutrients=')

parsed_nutr = json.loads(response.content)

# %%
parsed_nutr.keys()
# Out:
# dict_keys(['fdcId', 'description', 'publicationDate', 'foodNutrients', 'dataType', 'foodClass', 'inputFoods', 'foodComponents', 'foodAttributes', 'nutrientConversionFactors', 'ndbNumber', 'isHistoricalReference', 'foodCategory'])

# %%
parsed_nutr
# Out:
# 19',
#        'storeCity': '13550 W 63RD ST NE SHAWNEE',
#        'storeState': 'KS'},
#       {'sampleUnitId': 790279,
#        'purchaseDate': '11/16/2019',
#        'storeCity': '13550 W 63RD ST NE SHAWNEE',
#        'storeState': 'KS'}]},
#     {'subSampleId': 790368,
#      'nutrientId': 1226,
#      'amount': 0.07,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790366,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790365,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790386,
#      'nutrientId': 1226,
#      'amount': 0.05,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790383,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790384,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790408,
#      'nutrientId': 1226,
#      'amount': 0.07,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790405,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790406,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790423,
#      'nutrientId': 1226,
#      'amount': 0.06,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790420,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790421,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790442,
#      'nutrientId': 1226,
#      'amount': 0.06,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790439,
#        'purchaseDate': '11/17/2019',
#        'storeCity': '13335 SHAWNEE MISSON PKWAY SHAWNEE',
#        'storeState': 'KS'},
#       {'sampleUnitId': 790440,
#        'purchaseDate': '11/17/2019',
#        'storeCity': '13335 SHAWNEE MISSON PKWAY SHAWNEE',
#        'storeState': 'KS'}]}]},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1227,
#     'number': '518',
#     'name': 'Serine',
#     'rank': 18000,
#     'unitName': 'g'},
#    'foodNutrientDerivation': {'id': 1,
#     'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'id': 9638295,
#    'amount': 0.037,
#    'dataPoints': 6,
#    'max': 0.04,
#    'min': 0.03,
#    'median': 0.04,
#    'minYearAcquired': 2019,
#    'nutrientAnalysisDetails': [{'subSampleId': 790281,
#      'nutrientId': 1227,
#      'amount': 0.04,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790278,
#        'purchaseDate': '11/16/2019',
#        'storeCity': '13550 W 63RD ST NE SHAWNEE',
#        'storeState': 'KS'},
#       {'sampleUnitId': 790279,
#        'purchaseDate': '11/16/2019',
#        'storeCity': '13550 W 63RD ST NE SHAWNEE',
#        'storeState': 'KS'}]},
#     {'subSampleId': 790368,
#      'nutrientId': 1227,
#      'amount': 0.04,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790366,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790365,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790386,
#      'nutrientId': 1227,
#      'amount': 0.03,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790383,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790384,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790408,
#      'nutrientId': 1227,
#      'amount': 0.04,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790405,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790406,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790423,
#      'nutrientId': 1227,
#      'amount': 0.03,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790420,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790421,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790442,
#      'nutrientId': 1227,
#      'amount': 0.04,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790439,
#        'purchaseDate': '11/17/2019',
#        'storeCity': '13335 SHAWNEE MISSON PKWAY SHAWNEE',
#        'storeState': 'KS'},
#       {'sampleUnitId': 790440,
#        'purchaseDate': '11/17/2019',
#        'storeCity': '13335 SHAWNEE MISSON PKWAY SHAWNEE',
#        'storeState': 'KS'}]}]},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1228,
#     'number': '521',
#     'name': 'Hydroxyproline',
#     'rank': 18100,
#     'unitName': 'g'},
#    'foodNutrientDerivation': {'id': 1,
#     'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'id': 9638347,
#    'amount': 0.0,
#    'dataPoints': 6,
#    'max': 0.0,
#    'min': 0.0,
#    'median': 0.0,
#    'minYearAcquired': 2019,
#    'nutrientAnalysisDetails': [{'subSampleId': 790281,
#      'nutrientId': 1228,
#      'amount': 0.0,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790278,
#        'purchaseDate': '11/16/2019',
#        'storeCity': '13550 W 63RD ST NE SHAWNEE',
#        'storeState': 'KS'},
#       {'sampleUnitId': 790279,
#        'purchaseDate': '11/16/2019',
#        'storeCity': '13550 W 63RD ST NE SHAWNEE',
#        'storeState': 'KS'}]},
#     {'subSampleId': 790368,
#      'nutrientId': 1228,
#      'amount': 0.0,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790366,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790365,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790386,
#      'nutrientId': 1228,
#      'amount': 0.0,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790383,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790384,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790408,
#      'nutrientId': 1228,
#      'amount': 0.0,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790405,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790406,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790423,
#      'nutrientId': 1228,
#      'amount': 0.0,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790420,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790421,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790442,
#      'nutrientId': 1228,
#      'amount': 0.0,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790439,
#        'purchaseDate': '11/17/2019',
#        'storeCity': '13335 SHAWNEE MISSON PKWAY SHAWNEE',
#        'storeState': 'KS'},
#       {'sampleUnitId': 790440,
#        'purchaseDate': '11/17/2019',
#        'storeCity': '13335 SHAWNEE MISSON PKWAY SHAWNEE',
#        'storeState': 'KS'}]}]},
#   {'type': 'FoodNutrient',
#    'nutrient': {'id': 1232,
#     'number': '526',
#     'name': 'Cysteine',
#     'rank': 999999,
#     'unitName': 'g'},
#    'foodNutrientDerivation': {'id': 1,
#     'code': 'A',
#     'description': 'Analytical',
#     'foodNutrientSource': {'id': 1,
#      'code': '1',
#      'description': 'Analytical or derived from analytical'}},
#    'id': 9638346,
#    'amount': 0.0,
#    'dataPoints': 6,
#    'max': 0.0,
#    'min': 0.0,
#    'median': 0.0,
#    'minYearAcquired': 2019,
#    'nutrientAnalysisDetails': [{'subSampleId': 790281,
#      'nutrientId': 1232,
#      'amount': 0.0,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790278,
#        'purchaseDate': '11/16/2019',
#        'storeCity': '13550 W 63RD ST NE SHAWNEE',
#        'storeState': 'KS'},
#       {'sampleUnitId': 790279,
#        'purchaseDate': '11/16/2019',
#        'storeCity': '13550 W 63RD ST NE SHAWNEE',
#        'storeState': 'KS'}]},
#     {'subSampleId': 790368,
#      'nutrientId': 1232,
#      'amount': 0.0,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790366,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790365,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790386,
#      'nutrientId': 1232,
#      'amount': 0.0,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790383,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790384,
#        'purchaseDate': '11/18/2019',
#        'storeCity': '903 UNIV. CITY BLVD. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790408,
#      'nutrientId': 1232,
#      'amount': 0.0,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790405,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790406,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790423,
#      'nutrientId': 1232,
#      'amount': 0.0,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790420,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'},
#       {'sampleUnitId': 790421,
#        'purchaseDate': '11/25/2019',
#        'storeCity': '1413 N MAIN ST. BLACKSBURG',
#        'storeState': 'VA'}]},
#     {'subSampleId': 790442,
#      'nutrientId': 1232,
#      'amount': 0.0,
#      'labMethodTechnique': 'HPLC',
#      'labMethodDescription': 'USDA Guidebook 1986',
#      'labMethodOriginalDescription': 'USDA Guidebook 1986, Method 6.011',
#      'nutrientAcquisitionDetails': [{'sampleUnitId': 790439,
#        'purchaseDate': '11/17/2019',
#        'storeCity': '13335 SHAWNEE MISSON PKWAY SHAWNEE',
#        'storeState': 'KS'},
#       {'sampleUnitId': 790440,
#        'purchaseDate': '11/17/2019',
#        'storeCity': '13335 SHAWNEE MISSON PKWAY SHAWNEE',
#        'storeState': 'KS'}]}]}],
#  'dataType': 'Foundation',
#  'foodClass': 'FinalFood',
#  'inputFoods': [{'id': 78237,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790294,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}},
#   {'id': 78239,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790327,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}},
#   {'id': 78247,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790475,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}},
#   {'id': 78236,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790277,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}},
#   {'id': 78244,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790419,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}},
#   {'id': 78246,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790459,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}},
#   {'id': 78240,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790344,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}},
#   {'id': 78245,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790438,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}},
#   {'id': 78242,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790382,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}},
#   {'id': 78241,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790364,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}},
#   {'id': 78248,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790491,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}},
#   {'id': 78238,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790312,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}},
#   {'id': 78243,
#    'foodDescription': 'BUTTER, STICK, SALTED',
#    'inputFood': {'fdcId': 790404,
#     'description': 'BUTTER, STICK, SALTED',
#     'publicationDate': '4/1/2020',
#     'foodAttributeTypes': [],
#     'foodClass': 'Composite',
#     'totalRefuse': 0,
#     'dataType': 'Sample',
#     'foodGroup': {'id': 1,
#      'code': '0100',
#      'description': 'Dairy and Egg Products'}}}],
#  'foodComponents': [],
#  'foodAttributes': [],
#  'nutrientConversionFactors': [],
#  'ndbNumber': 1001,
#  'isHistoricalReference': False,
#  'foodCategory': {'id': 1,
#   'code': '0100',
#   'description': 'Dairy and Egg Products'}}

# %%
# uses 100g or 100ml serving sizes
