# %%
# import dependencies
import requests
import json
import numpy as np
import pandas as pd

# import api key from config
api_key = 'DEMO_KEY'

# %%
# make a call
requested_url = 'https://api.nal.usda.gov/fdc/v1/search?api_key='

headers = {'Content-Type': 'application/json'}

item = 'milk'

# pull item in list
data = {"generalSearchInput": 'butter'}
# convert to json format
data_str = json.dumps(data).encode("utf-8")

# make call
response = requests.get(requested_url + api_key + '&query=' + item)

parsed = json.loads(response.content)

# %%
fdcId = parsed['foods'][0]['fdcId']
fdcId
# Out:
# 1116276

# %%
# make a call
requested_nutr_url = f'https://api.nal.usda.gov/fdc/v1/food/{fdcId}?api_key='


# make call
response = requests.get('https://api.nal.usda.gov/fdc/v1/food/1116276?api_key=DEMO_KEY')

parsed_nutr = json.loads(response.content)

# %%
parsed['foods']
# Out:
# ': '2019-04-01',
#   'brandOwner': 'Price Chopper Supermarkets',
#   'ingredients': 'MILK, VITAMIN D3.',
#   'allHighlightFields': '<b>Ingredients</b>: <em>MILK</em>, VITAMIN D3.',
#   'score': 539.954,
#   'foodNutrients': [{'nutrientId': 1079,
#     'nutrientName': 'Fiber, total dietary',
#     'nutrientNumber': '291',
#     'unitName': 'G',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1087,
#     'nutrientName': 'Calcium, Ca',
#     'nutrientNumber': '301',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 125},
#    {'nutrientId': 1089,
#     'nutrientName': 'Iron, Fe',
#     'nutrientNumber': '303',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1104,
#     'nutrientName': 'Vitamin A, IU',
#     'nutrientNumber': '318',
#     'unitName': 'IU',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 125},
#    {'nutrientId': 1110,
#     'nutrientName': 'Vitamin D (D2 + D3), International Units',
#     'nutrientNumber': '324',
#     'unitName': 'IU',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 42.0},
#    {'nutrientId': 1162,
#     'nutrientName': 'Vitamin C, total ascorbic acid',
#     'nutrientNumber': '401',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 1.0},
#    {'nutrientId': 1003,
#     'nutrientName': 'Protein',
#     'nutrientNumber': '203',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 3.33},
#    {'nutrientId': 1004,
#     'nutrientName': 'Total lipid (fat)',
#     'nutrientNumber': '204',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 3.33},
#    {'nutrientId': 1005,
#     'nutrientName': 'Carbohydrate, by difference',
#     'nutrientNumber': '205',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 5.0},
#    {'nutrientId': 1008,
#     'nutrientName': 'Energy',
#     'nutrientNumber': '208',
#     'unitName': 'KCAL',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 62.0},
#    {'nutrientId': 2000,
#     'nutrientName': 'Sugars, total including NLEA',
#     'nutrientNumber': '269',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 4.58},
#    {'nutrientId': 1093,
#     'nutrientName': 'Sodium, Na',
#     'nutrientNumber': '307',
#     'unitName': 'MG',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 50.0},
#    {'nutrientId': 1253,
#     'nutrientName': 'Cholesterol',
#     'nutrientNumber': '601',
#     'unitName': 'MG',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 15.0},
#    {'nutrientId': 1257,
#     'nutrientName': 'Fatty acids, total trans',
#     'nutrientNumber': '605',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1258,
#     'nutrientName': 'Fatty acids, total saturated',
#     'nutrientNumber': '606',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 2.08}]},
#  {'fdcId': 506876,
#   'description': 'MILK',
#   'lowercaseDescription': 'milk',
#   'dataType': 'Branded',
#   'gtinUpc': '071156500676',
#   'publishedDate': '2019-04-01',
#   'brandOwner': 'Rutter Bros. Dairy, Inc.',
#   'ingredients': 'MILK WITH 400 I.U. OF VITAMIN D3 ADDED PER QUART.',
#   'allHighlightFields': '<b>Ingredients</b>: <em>MILK</em> WITH 400 I.U. OF VITAMIN D3 ADDED PER QUART.',
#   'score': 539.954,
#   'foodNutrients': [{'nutrientId': 1079,
#     'nutrientName': 'Fiber, total dietary',
#     'nutrientNumber': '291',
#     'unitName': 'G',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1087,
#     'nutrientName': 'Calcium, Ca',
#     'nutrientNumber': '301',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 125},
#    {'nutrientId': 1089,
#     'nutrientName': 'Iron, Fe',
#     'nutrientNumber': '303',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1104,
#     'nutrientName': 'Vitamin A, IU',
#     'nutrientNumber': '318',
#     'unitName': 'IU',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 125},
#    {'nutrientId': 1110,
#     'nutrientName': 'Vitamin D (D2 + D3), International Units',
#     'nutrientNumber': '324',
#     'unitName': 'IU',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 42.0},
#    {'nutrientId': 1162,
#     'nutrientName': 'Vitamin C, total ascorbic acid',
#     'nutrientNumber': '401',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1003,
#     'nutrientName': 'Protein',
#     'nutrientNumber': '203',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 3.33},
#    {'nutrientId': 1004,
#     'nutrientName': 'Total lipid (fat)',
#     'nutrientNumber': '204',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 3.33},
#    {'nutrientId': 1005,
#     'nutrientName': 'Carbohydrate, by difference',
#     'nutrientNumber': '205',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 5.0},
#    {'nutrientId': 1008,
#     'nutrientName': 'Energy',
#     'nutrientNumber': '208',
#     'unitName': 'KCAL',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 62.0},
#    {'nutrientId': 2000,
#     'nutrientName': 'Sugars, total including NLEA',
#     'nutrientNumber': '269',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 5.0},
#    {'nutrientId': 1093,
#     'nutrientName': 'Sodium, Na',
#     'nutrientNumber': '307',
#     'unitName': 'MG',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 44.0},
#    {'nutrientId': 1253,
#     'nutrientName': 'Cholesterol',
#     'nutrientNumber': '601',
#     'unitName': 'MG',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 10.0},
#    {'nutrientId': 1257,
#     'nutrientName': 'Fatty acids, total trans',
#     'nutrientNumber': '605',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1258,
#     'nutrientName': 'Fatty acids, total saturated',
#     'nutrientNumber': '606',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 2.08}]},
#  {'fdcId': 523854,
#   'description': 'MILK',
#   'lowercaseDescription': 'milk',
#   'dataType': 'Branded',
#   'gtinUpc': '021130071005',
#   'publishedDate': '2019-04-01',
#   'brandOwner': 'Safeway, Inc.',
#   'ingredients': 'MILK, VITAMIN D3.',
#   'allHighlightFields': '<b>Ingredients</b>: <em>MILK</em>, VITAMIN D3.',
#   'score': 539.954,
#   'foodNutrients': [{'nutrientId': 1079,
#     'nutrientName': 'Fiber, total dietary',
#     'nutrientNumber': '291',
#     'unitName': 'G',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1089,
#     'nutrientName': 'Iron, Fe',
#     'nutrientNumber': '303',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1003,
#     'nutrientName': 'Protein',
#     'nutrientNumber': '203',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 3.75},
#    {'nutrientId': 1004,
#     'nutrientName': 'Total lipid (fat)',
#     'nutrientNumber': '204',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 3.33},
#    {'nutrientId': 1005,
#     'nutrientName': 'Carbohydrate, by difference',
#     'nutrientNumber': '205',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 5.42},
#    {'nutrientId': 1008,
#     'nutrientName': 'Energy',
#     'nutrientNumber': '208',
#     'unitName': 'KCAL',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 67.0},
#    {'nutrientId': 2000,
#     'nutrientName': 'Sugars, total including NLEA',
#     'nutrientNumber': '269',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 5.0},
#    {'nutrientId': 1087,
#     'nutrientName': 'Calcium, Ca',
#     'nutrientNumber': '301',
#     'unitName': 'MG',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 131},
#    {'nutrientId': 1092,
#     'nutrientName': 'Potassium, K',
#     'nutrientNumber': '306',
#     'unitName': 'MG',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 174},
#    {'nutrientId': 1093,
#     'nutrientName': 'Sodium, Na',
#     'nutrientNumber': '307',
#     'unitName': 'MG',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 56.0},
#    {'nutrientId': 1253,
#     'nutrientName': 'Cholesterol',
#     'nutrientNumber': '601',
#     'unitName': 'MG',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 15.0},
#    {'nutrientId': 1257,
#     'nutrientName': 'Fatty acids, total trans',
#     'nutrientNumber': '605',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1258,
#     'nutrientName': 'Fatty acids, total saturated',
#     'nutrientNumber': '606',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 2.08}]},
#  {'fdcId': 488891,
#   'description': 'MILK',
#   'lowercaseDescription': 'milk',
#   'dataType': 'Branded',
#   'gtinUpc': '071580001749',
#   'publishedDate': '2019-04-01',
#   'brandOwner': 'Quality Chekd Dairies, Inc.',
#   'ingredients': 'MILK, CORN SYRUP SOLIDS, ARTIFICIAL FLAVORS, CITRIC ACID, ARTIFICIAL COLOR, SALT, VITAMIN D3.',
#   'allHighlightFields': '<b>Ingredients</b>: <em>MILK</em>, CORN SYRUP SOLIDS, ARTIFICIAL FLAVORS, CITRIC ACID, ARTIFICIAL COLOR, SALT, VITAMIN D3.',
#   'score': 539.954,
#   'foodNutrients': [{'nutrientId': 1079,
#     'nutrientName': 'Fiber, total dietary',
#     'nutrientNumber': '291',
#     'unitName': 'G',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1087,
#     'nutrientName': 'Calcium, Ca',
#     'nutrientNumber': '301',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 83.0},
#    {'nutrientId': 1089,
#     'nutrientName': 'Iron, Fe',
#     'nutrientNumber': '303',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1104,
#     'nutrientName': 'Vitamin A, IU',
#     'nutrientNumber': '318',
#     'unitName': 'IU',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 125},
#    {'nutrientId': 1110,
#     'nutrientName': 'Vitamin D (D2 + D3), International Units',
#     'nutrientNumber': '324',
#     'unitName': 'IU',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 42.0},
#    {'nutrientId': 1162,
#     'nutrientName': 'Vitamin C, total ascorbic acid',
#     'nutrientNumber': '401',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1003,
#     'nutrientName': 'Protein',
#     'nutrientNumber': '203',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 2.5},
#    {'nutrientId': 1004,
#     'nutrientName': 'Total lipid (fat)',
#     'nutrientNumber': '204',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 2.92},
#    {'nutrientId': 1005,
#     'nutrientName': 'Carbohydrate, by difference',
#     'nutrientNumber': '205',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 11.7},
#    {'nutrientId': 1008,
#     'nutrientName': 'Energy',
#     'nutrientNumber': '208',
#     'unitName': 'KCAL',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 79.0},
#    {'nutrientId': 2000,
#     'nutrientName': 'Sugars, total including NLEA',
#     'nutrientNumber': '269',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 11.2},
#    {'nutrientId': 1093,
#     'nutrientName': 'Sodium, Na',
#     'nutrientNumber': '307',
#     'unitName': 'MG',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 42.0},
#    {'nutrientId': 1253,
#     'nutrientName': 'Cholesterol',
#     'nutrientNumber': '601',
#     'unitName': 'MG',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 12.0},
#    {'nutrientId': 1258,
#     'nutrientName': 'Fatty acids, total saturated',
#     'nutrientNumber': '606',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 1.67}]},
#  {'fdcId': 488892,
#   'description': 'MILK',
#   'lowercaseDescription': 'milk',
#   'dataType': 'Branded',
#   'gtinUpc': '071203001910',
#   'publishedDate': '2019-04-01',
#   'brandOwner': 'Umpqua Dairy Products Co.',
#   'ingredients': 'MILK, CORN SYRUP SOLIDS, WHITE GRAPE JUICE CONCENTRATE, NATURAL & ARTIFICIAL FLAVORS, RED 40, BLUE 1, CARRAGEENAN, VITAMIN D3 ADDED.',
#   'allHighlightFields': '<b>Ingredients</b>: <em>MILK</em>, CORN SYRUP SOLIDS, WHITE GRAPE JUICE CONCENTRATE, NATURAL & ARTIFICIAL FLAVORS, RED 40, BLUE 1, CARRAGEENAN, VITAMIN D3 ADDED.',
#   'score': 539.954,
#   'foodNutrients': [{'nutrientId': 1079,
#     'nutrientName': 'Fiber, total dietary',
#     'nutrientNumber': '291',
#     'unitName': 'G',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1087,
#     'nutrientName': 'Calcium, Ca',
#     'nutrientNumber': '301',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 104},
#    {'nutrientId': 1089,
#     'nutrientName': 'Iron, Fe',
#     'nutrientNumber': '303',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.0},
#    {'nutrientId': 1104,
#     'nutrientName': 'Vitamin A, IU',
#     'nutrientNumber': '318',
#     'unitName': 'IU',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 125},
#    {'nutrientId': 1110,
#     'nutrientName': 'Vitamin D (D2 + D3), International Units',
#     'nutrientNumber': '324',
#     'unitName': 'IU',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 42.0},
#    {'nutrientId': 1162,
#     'nutrientName': 'Vitamin C, total ascorbic acid',
#     'nutrientNumber': '401',
#     'unitName': 'MG',
#     'derivationCode': 'LCCD',
#     'derivationDescription': 'Calculated from a daily value percentage per serving size measure',
#     'value': 0.5},
#    {'nutrientId': 1003,
#     'nutrientName': 'Protein',
#     'nutrientNumber': '203',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 2.5},
#    {'nutrientId': 1004,
#     'nutrientName': 'Total lipid (fat)',
#     'nutrientNumber': '204',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 2.92},
#    {'nutrientId': 1005,
#     'nutrientName': 'Carbohydrate, by difference',
#     'nutrientNumber': '205',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 11.7},
#    {'nutrientId': 1008,
#     'nutrientName': 'Energy',
#     'nutrientNumber': '208',
#     'unitName': 'KCAL',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 83.0},
#    {'nutrientId': 2000,
#     'nutrientName': 'Sugars, total including NLEA',
#     'nutrientNumber': '269',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 11.2},
#    {'nutrientId': 1093,
#     'nutrientName': 'Sodium, Na',
#     'nutrientNumber': '307',
#     'unitName': 'MG',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 48.0},
#    {'nutrientId': 1253,
#     'nutrientName': 'Cholesterol',
#     'nutrientNumber': '601',
#     'unitName': 'MG',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 12.0},
#    {'nutrientId': 1258,
#     'nutrientName': 'Fatty acids, total saturated',
#     'nutrientNumber': '606',
#     'unitName': 'G',
#     'derivationCode': 'LCCS',
#     'derivationDescription': 'Calculated from value per serving size measure',
#     'value': 1.88}]}]
