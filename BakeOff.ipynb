# %%
import pandas as pd
import numpy as np
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup

# %%
# Set the executable path and initialize the chrome browser in splinter

executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
url = 'https://thegreatbritishbakeoff.co.uk/recipes/all/?filter[collection]=81&showFilter=false'
browser.visit(url)
browser.links.find_by_partial_text('OK').click()

# %%
#Last page of the browser
last_url = browser.find_by_css('a.page-numbers')[-1].value
last_url
# Out:
# '11'

# %%
# Creating an empty list to store the titles, image, servings
technical_list=[]

# Creating an empty dictionary
technical_dict ={'title':[], 'judge':[], 'makes':[], 'difficulty':[], 'hands_on_time':[], 'baking_time':[], 'ingredients':[], 'recipe_image':[], 'judge_image':[]}

# %%
def page(browser):
    for i in range(12):
                        
                # loading the page
                browser.find_by_css("div.recipes-loop__item.collection", wait_time=1)[i].click()
                recipe_html = browser.html
                recipe_soup = soup(recipe_html, 'html.parser')
                title = recipe_soup.find('h1').text
                h5=recipe_soup.find('h5')
                
                global j0
                try:
                    j0 = recipe_soup.h5.find('a').text
                except AttributeError:
                    print("judge not found")                    
                judge = j0
                
                global x0
                try:
                    x0 = recipe_soup.find_all('div', class_='recipe-details__item')[0]
                except UnboundLocalError:
                    print("not found")
                except IndexError:
                    print("not found")
                makes = x0.find('span', class_='value').get_text()

                global x1
                try:
                    x1 = recipe_soup.find_all('div', class_='recipe-details__item')[1]
                except UnboundLocalError:
                    print("not found")
                except IndexError:
                    print("not found")
                difficulty = x1.find('span', class_='value').get_text()
    
                global x2
                try:
                    x2 = recipe_soup.find_all('div', class_='recipe-details__item')[2]
                except UnboundLocalError:
                    print("not found")
                except IndexError:
                    print("not found")
                hands_on_time = x2.find('span', class_='value').get_text()
                
                global x3
                try:
                    x3 = recipe_soup.find_all('div', class_='recipe-details__item')[3]
                except UnboundLocalError:
                    print("not found")
                except IndexError:
                    print("not found")                
                baking_time = x3.find('span', class_='value').get_text()
            
                ingredients = recipe_soup.find('div', class_='recipe-sidebar__section recipe-sidebar__section--ingredients').findAll('p')

                container = recipe_soup.find('div', class_='container')
                recipe_image = container.find_all('img')[0].get('src')
                
                global j1
                try:
                    j1 = container.find_all('img')[1].get('src')
                except UnboundLocalError:
                    print("not found")
                except IndexError:
                    print("judge not found")                
                judge_image = j1
                    


                # Creating dictionary keys
                technical_dict['title'].append(title)
                technical_dict['judge'].append(judge)
                technical_dict['makes'].append(makes)
                technical_dict['difficulty'].append(difficulty)
                technical_dict['hands_on_time'].append(hands_on_time)
                technical_dict['baking_time'].append(baking_time)
                technical_dict['ingredients'].append(ingredients)
                technical_dict['recipe_image'].append(recipe_image)
                technical_dict['judge_image'].append(judge_image)

                technical_dictionary = {'title':title, 'judge':judge, 'makes':makes, 'difficulty':difficulty, 'hands_on_time':hands_on_time, 'baking_time':baking_time, 'ingredients':ingredients, 'recipe_image':recipe_image, 'judge_image':judge_image}

                technical_list.append(technical_dictionary)

                browser.back()
    return technical_list

# %%
for j in range(2, int(last_url)):

    link1 = 'https://thegreatbritishbakeoff.co.uk/recipes/all/page/'
    link2 = '/?filter%5Bcollection%5D=81&showFilter=false#038;showFilter=false'

    browser.links.find_by_href(link1+str(j)+link2).click()
    page(browser)
# Out:
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# judge not found
# judge not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# judge not found
# not found
# not found
# not found
# judge not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# judge not found
# not found
# not found
# not found
# not found
# judge not found
# judge not found
# not found
# not found
# not found
# judge not found
# judge not found
# not found
# not found
# not found
# judge not found
# judge not found
# not found
# not found
# not found
# judge not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# not found
# not found
# not found
# judge not found
# not found
# not found
# not found
# judge not found
# judge not found
# not found
# not found
# not found
# judge not found

# %%
technical_list_df = pd.DataFrame(technical_list)
technical_list_df
# Out:
#                                                title           judge  \
# 0                  Prue Leith’s Sussex Pond Puddings      Prue Leith
# 1           Paul Hollywood’s Jam & Custard Doughnuts  Paul Hollywood
# 2               Prue Leith’s Matcha Mille Crêpe Cake      Prue Leith
# 3    Prue Leith’s Raspberry & Salted Caramel Éclairs      Prue Leith
# 4                   Paul Hollywood’s Chocolate Babka  Paul Hollywood
# ..                                               ...             ...
# 103           Mary Berry’s Frosted Walnut Layer Cake  Paul Hollywood
# 104                         Paul Hollywood’s Stollen  Paul Hollywood
# 105                        Paul Hollywood’s Pretzels  Paul Hollywood
# 106                  Mary Berry’s Hazelnut Dacquoise  Paul Hollywood
# 107                         Mary Berry’s Religieuses  Paul Hollywood
#
#                      makes              difficulty hands_on_time baking_time  \
# 0                    2 - 4                    Easy       30 mins       2 hrs
# 1                        6             Needs skill       30 mins     20 mins
# 2                       10             Needs skill  1 hr 20 mins     40 mins
# 3                        6             Challenging  1 hr 30 mins     30 mins
# 4                   1 loaf             Needs skill       30 mins     45 mins
# ..                     ...                     ...           ...         ...
# 103                   8-10  30 mins, plus chilling    25–30 mins     18 mins
# 104                  10–12  30 mins, plus chilling    25–30 mins     18 mins
# 105  6 savoury and 6 sweet  30 mins, plus chilling    25–30 mins     18 mins
# 106                     12  30 mins, plus chilling    25–30 mins     18 mins
# 107                      8  30 mins, plus chilling    25–30 mins     18 mins
#
#                                            ingredients  \
# 0    [[110g self-raising flour, plus extra for dust...
# 1    [l whole milk ], [1 large egg ], [250g st...
# 2    [l whole milk ], [45g caster sugar ], [3 ...
# 3    [[45g strong white bread flour], [45g plain fl...
# 4    [[65g blanched hazelnuts], [100g unsalted butt...
# ..                                                 ...
# 103  [[225g self-raising flour], [1 tsp baking powd...
# 104  [[500g strong white flour], [100g caster sugar...
# 105  [[500g strong white bread flour], [10g salt], ...
# 106  [[250g blanched (skinned) whole hazelnuts], [3...
# 107  [[60g unsalted butter, cubed], l water], ...
#
#                                           recipe_image  \
# 0    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 1    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 2    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 3    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 4    https://thegreatbritishbakeoff.co.uk/wp-conten...
# ..                                                 ...
# 103  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 104  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 105  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 106  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 107  https://thegreatbritishbakeoff.co.uk/wp-conten...
#
#                                            judge_image
# 0    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 1    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 2    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 3    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 4    https://thegreatbritishbakeoff.co.uk/wp-conten...
# ..                                                 ...
# 103  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 104  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 105  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 106  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 107  https://thegreatbritishbakeoff.co.uk/wp-conten...
#
# [108 rows x 9 columns]
