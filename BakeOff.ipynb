# %%
import pandas as pd
import numpy as np
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup

# %%
# Set the executable path and initialize the chrome browser in splinter

executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
url = 'https://thegreatbritishbakeoff.co.uk/recipes/all/?filter[collection]=81&showFilter=false'
browser.visit(url)
browser.links.find_by_partial_text('OK').click()

# %%
#Last page of the browser
last_url = browser.find_by_css('a.page-numbers')[-1].value
last_url
# Out:
# '11'

# %%
# Creating an empty list to store the titles, image, servings
technical_list=[]

# Creating an empty dictionary
technical_dict ={'title':[], 'judge':[], 'makes':[], 'difficulty':[], 'hands_on_time':[], 'baking_time':[], 'ingredients':[], 'recipe_image':[], 'judge_image':[]}

# %%
def page(browser):
    for i in range(12):
                        
                # loading the page
                browser.find_by_css("div.recipes-loop__item.collection", wait_time=1)[i].click()
                recipe_html = browser.html
                recipe_soup = soup(recipe_html, 'html.parser')
                title = recipe_soup.find('h1').text
                h5=recipe_soup.find('h5')
                
                try:
                    j0 = recipe_soup.h5.find('a').text
                except AttributeError:
                    print("judge not found")                    
                judge = j0
                
                
                try:
                    x0 = recipe_soup.find_all('div', class_='recipe-details__item')[0]
                except UnboundLocalError:
                    print("not found")
                makes = x0.find('span', class_='value').get_text()

                try:
                    x1 = recipe_soup.find_all('div', class_='recipe-details__item')[1]
                except IndexError:
                    print("not found")
                difficulty = x1.find('span', class_='value').get_text()
    
                try:
                    x2 = recipe_soup.find_all('div', class_='recipe-details__item')[2]
                except IndexError:
                    print("not found")
                hands_on_time = x2.find('span', class_='value').get_text()

                try:
                    x3 = recipe_soup.find_all('div', class_='recipe-details__item')[3]
                except IndexError:
                    print("not found")                
                baking_time = x3.find('span', class_='value').get_text()
            
                ingredients = recipe_soup.find('div', class_='recipe-sidebar__section recipe-sidebar__section--ingredients').findAll('p')

                container = recipe_soup.find('div', class_='container')
                recipe_image = container.find_all('img')[0].get('src')
                
                try:
                    j1 = container.find_all('img')[1].get('src')
                except IndexError:
                    print("judge not found")                
                judge_image = j1
                    


                # Creating dictionary keys
                technical_dict['title'].append(title)
                technical_dict['judge'].append(judge)
                technical_dict['makes'].append(makes)
                technical_dict['difficulty'].append(difficulty)
                technical_dict['hands_on_time'].append(hands_on_time)
                technical_dict['baking_time'].append(baking_time)
                technical_dict['ingredients'].append(ingredients)
                technical_dict['recipe_image'].append(recipe_image)
                technical_dict['judge_image'].append(judge_image)

                technical_dictionary = {'title':title, 'judge':judge, 'makes':makes, 'difficulty':difficulty, 'hands_on_time':hands_on_time, 'baking_time':baking_time, 'ingredients':ingredients, 'recipe_image':recipe_image, 'judge_image':judge_image}

                technical_list.append(technical_dictionary)

                browser.back()
    return technical_list

# %%
page(browser)
# Out:
# [{'title': 'Rav Gill’s Tiger Pretzels',
#   'judge': 'Ravneet Gill',
#   'makes': '4',
#   'difficulty': 'Needs skill',
#   'hands_on_time': '45 mins',
#   'baking_time': '15 mins',
#   'ingredients': [<p>180ml warm water </p>,
#    <p>4g active dried yeast </p>,
#    <p>10g unsalted butter, melted </p>,
#    <p>2 tsp caster sugar </p>,
#    <p>240g plain flour, plus extra for dusting</p>,
#    <p>½ tsp fine salt</p>,
#    <p>Black, orange and yellow food-colouring gels</p>,
#    <p>Sea salt, for sprinkling</p>,
#    <p>Sesame seeds, for sprinkling </p>,
#    <p>1 tsp bicarbonate of soda </p>,
#    <p>2 tsp caster sugar </p>,
#    <p>140g unsalted butter, softened</p>,
#    <p>50g parmesan, grated</p>,
#    <p>1 tsp paprika, or hot or sweet smoked paprika </p>,
#    <p>Freshly ground black pepper</p>],
#   'recipe_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2021/01/Tiger-pretzels-1024x450.jpg',
#   'judge_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2021/01/Ravneet_Gill_2021_1024-100x100.png'},
#  {'title': 'Liam Charles’s Chocolate Marshmallow Biscuits',
#   'judge': 'Liam Charles',
#   'makes': '4',
#   'difficulty': 'Needs skill',
#   'hands_on_time': '45 mins',
#   'baking_time': '12 mins',
#   'ingredients': [<p>50g plain flour, plus extra for dusting</p>,
#    <p>½ tsp baking powder</p>,
#    <p>¼ tsp fine salt</p>,
#    <p>25g cocoa powder</p>,
#    <p>25g wholemeal flour</p>,
#    <p>25g caster sugar </p>,
#    <p>25g unsalted butter, cubed and chilled</p>,
#    <p>1 large egg yolk</p>,
#    <p>2 tbsp whole milk</p>,
#    <p>2 platinum-grade gelatine leaves</p>,
#    <p>2 large egg whites </p>,
#    <p>½ tsp vanilla paste</p>,
#    <p>150g caster sugar </p>,
#    <p>175g 70% dark chocolate, roughly chopped </p>,
#    <p>40g coconut oil </p>,
#    <p>Ready-to-roll pink fondant icing</p>,
#    <p>8 edible sugar eyes </p>],
#   'recipe_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2021/01/Marshmallow-1024x450.jpg',
#   'judge_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2020/08/Liam_Charles_2019_1024-100x100.png'},
#  {'title': 'Rav Gill’s Chess Cake',
#   'judge': 'Ravneet Gill',
#   'makes': '8',
#   'difficulty': 'Needs skill',
#   'hands_on_time': '40 mins',
#   'baking_time': '20 mins',
#   'ingredients': [<p>225g unsalted butter</p>,
#    <p>225g caster sugar</p>,
#    <p>225g self-raising flour</p>,
#    <p>2 tsp baking powder</p>,
#    <p>4 large eggs</p>,
#    <p>1 tsp vanilla extract</p>,
#    <p>2 tsp rose water </p>,
#    <p>Pink food-colouring gel</p>,
#    <p>2 tsp pistachio paste</p>,
#    <p>Green food-colouring gel </p>,
#    <p>550g icing sugar</p>,
#    <p>225g unsalted butter, softened</p>,
#    <p>4 tbsp double cream</p>,
#    <p>1½ tbsp pistachio paste</p>,
#    <p>½ tsp fine salt </p>,
#    <p>Slivered pistachios</p>,
#    <p>Rose petals </p>],
#   'recipe_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2021/01/Chess-cake-1024x450.jpg',
#   'judge_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2021/01/Ravneet_Gill_2021_1024-100x100.png'},
#  {'title': 'Liam Charles’s Caribbean Patties',
#   'judge': 'Liam Charles',
#   'makes': '2',
#   'difficulty': 'Needs skill',
#   'hands_on_time': '30 mins',
#   'baking_time': '30 mins',
#   'ingredients': [<p>200g plain flour, plus extra for dusting</p>,
#    <p>1 tsp ground turmeric</p>,
#    <p>Pinch of fine salt</p>,
#    <p>125g unsalted butter, frozen</p>,
#    <p>1 egg, beaten, to glaze</p>,
#    <p>1½ tsp cayenne pepper</p>,
#    <p>½ tsp hot smoked paprika</p>,
#    <p>½ tsp ground allspice</p>,
#    <p>½ tsp chilli flakes </p>,
#    <p>1 tsp dried thyme</p>,
#    <p>1 tsp dried parsley </p>,
#    <p>1 tsp garlic granules</p>,
#    <p>1 tsp onion granules</p>,
#    <p>1 tsp light brown soft sugar</p>,
#    <p>1 tsp fine salt</p>,
#    <p>¼ tsp freshly ground black pepper</p>,
#    <p>25g block creamed coconut, grated </p>,
#    <p>1 tbsp tomato purée</p>,
#    <p>20g frozen peas, defrosted</p>,
#    <p>20g sweetcorn </p>,
#    <p>½ tsp ginger paste</p>,
#    <p>½ tsp garlic paste </p>,
#    <p>½ small red chili, deseeded and finely chopped</p>,
#    <p>2 spring onions, finely sliced</p>,
#    <p>1 small carrot (about 30g), finely chopped into 7.5mm dice</p>,
#    <p>100g sweet potato, finely chopped into 7.5mm dice</p>,
#    <p>1 tbsp jerk seasoning</p>,
#    <p>50g coconut cream</p>,
#    <p>125g soured cream</p>,
#    <p>1 tbsp lime juice </p>,
#    <p>1 tbsp jerk seasoning</p>,
#    <p>1 tbsp runny honey</p>,
#    <p>Red food-colouring gel, diluted with a few drops of water</p>,
#    <p>Blue food-colouring gel, diluted with a few drops of water</p>],
#   'recipe_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2021/01/Patties-1024x450.jpg',
#   'judge_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2020/08/Liam_Charles_2019_1024-100x100.png'},
#  {'title': 'Rav Gill’s Soufflé Pancakes',
#   'judge': 'Ravneet Gill',
#   'makes': '4',
#   'difficulty': 'Needs skill',
#   'hands_on_time': '40 mins',
#   'baking_time': '30 mins',
#   'ingredients': [<p>200g mixed frozen berries</p>,
#    <p>2 tbsp caster sugar </p>,
#    <p>1 tbsp lemon juice </p>,
#    <p>3 tbsp whole milk </p>,
#    <p>3 large eggs, separated </p>,
#    <p>½ tsp vanilla extract</p>,
#    <p>15g mayonnaise </p>,
#    <p>75g plain flour</p>,
#    <p>1½ tbsp cornflour</p>,
#    <p>1½ tsp baking powder</p>,
#    <p>65g caster sugar </p>,
#    <p>Vegetable or sunflower oil, for greasing </p>],
#   'recipe_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2021/01/Souffle-pancakes-1024x450.jpg',
#   'judge_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2021/01/Ravneet_Gill_2021_1024-100x100.png'},
#  {'title': 'Liam Charles’s Pizza Star Bread',
#   'judge': 'Liam Charles',
#   'makes': '8',
#   'difficulty': 'Needs skill',
#   'hands_on_time': '30 mins',
#   'baking_time': '35 mins',
#   'ingredients': [<p>50g basil leaves</p>,
#    <p>30g parmesan, finely grated </p>,
#    <p>30g pine nuts</p>,
#    <p>1 tbsp lemon juice</p>,
#    <p>2 tbsp olive oil</p>,
#    <p>½ tsp salt</p>,
#    <p>350g self-raising flour, plus extra for dusting</p>,
#    <p>1 tsp baking powder</p>,
#    <p>½ tsp salt</p>,
#    <p>300g natural yoghurt </p>,
#    <p>4 tbsp passata</p>,
#    <p>100g pre-grated mozzarella, grated</p>,
#    <p>100g mayonnaise</p>,
#    <p>1 tbsp lemon juice </p>,
#    <p>1 tsp garlic paste</p>,
#    <p>Pinch of salt </p>,
#    <p>80g mayonnaise</p>,
#    <p>80g soured cream</p>,
#    <p>2 tsp white wine vinegar</p>,
#    <p>1 tsp garlic paste</p>,
#    <p>½ tsp dried oregano</p>,
#    <p>½ tsp dried parsley</p>,
#    <p>Pinch of salt </p>],
#   'recipe_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2021/01/Pizza-bread-1024x450.jpg',
#   'judge_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2020/08/Liam_Charles_2019_1024-100x100.png'},
#  {'title': 'Rav Gill’s Cookie Cups & Roasted Hazelnut Milk',
#   'judge': 'Ravneet Gill',
#   'makes': '4',
#   'difficulty': 'Needs skill',
#   'hands_on_time': '40 mins',
#   'baking_time': '20 mins',
#   'ingredients': [<p>100g unsalted butter, softened</p>,
#    <p>40g caster sugar </p>,
#    <p>50g light brown soft sugar </p>,
#    <p>1 egg yolk </p>,
#    <p>½ tsp vanilla extract</p>,
#    <p>140g plain flour </p>,
#    <p>½ tsp fine salt </p>,
#    <p>60g small milk chocolate chips </p>,
#    <p>150g 54% dark chocolate, broken into pieces</p>,
#    <p>250ml hazelnut milk</p>,
#    <p>1 tsp caster sugar</p>,
#    <p>Hazelnut paste</p>,
#    <p>Salt</p>],
#   'recipe_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2021/01/Cookie-cups-1024x450.jpg',
#   'judge_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2021/01/Ravneet_Gill_2021_1024-100x100.png'},
#  {'title': 'Liam Charles’s Strawberry & Custard Jaffa Cakes',
#   'judge': 'Liam Charles',
#   'makes': '6',
#   'difficulty': 'Needs skill',
#   'hands_on_time': '48 mins',
#   'baking_time': '12 mins',
#   'ingredients': [<p>1 x 135g pack of strawberry jelly</p>,
#    <p>150ml boiling water</p>,
#    <p>2 large eggs</p>,
#    <p>50g caster sugar</p>,
#    <p>50g self-raising flour, sifted</p>,
#    <p>20g custard powder, sifted</p>,
#    <p>200g 46% cocoa-solids chocolate, broken into pieces</p>,
#    <p>100g white chocolate, broken into pieces </p>],
#   'recipe_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2021/01/IMG_8059-1024x450.jpg',
#   'judge_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2020/08/Liam_Charles_2019_1024-100x100.png'},
#  {'title': 'Paul Hollywood’s Steamed Bao Buns with Crispy Duck',
#   'judge': 'Paul Hollywood',
#   'makes': '6',
#   'difficulty': 'Easy',
#   'hands_on_time': '30 mins, plus proving',
#   'baking_time': '10 mins',
#   'ingredients': [<p>130g plain flour, plus extra for dusting</p>,
#    <p>1 tsp caster sugar </p>,
#    <p>¼ tsp fast-action dried yeast</p>,
#    <p>1 tbsp whole milk</p>,
#    <p>1 tsp oil, plus extra for greasing</p>,
#    <p>1 tsp rice vinegar</p>,
#    <p>¼ tsp baking powder</p>,
#    <p>35g dark brown soft sugar </p>,
#    <p>2 tbsp black bean sauce </p>,
#    <p>1 tbsp dark soy sauce</p>,
#    <p>1½ tsp rice vinegar </p>,
#    <p>2 soft dried prunes</p>,
#    <p>¼ tsp sesame oil </p>,
#    <p>⅛ tsp Chinese five spice </p>,
#    <p>Ready-to-roast aromatic ½ crispy duck </p>,
#    <p>1 small carrot, peeled </p>,
#    <p>¼ cucumber </p>,
#    <p>2 spring onions, trimmed</p>,
#    <p>1 red chilli, thinly sliced on the diagonal, to garnish</p>,
#    <p>Coriander leaves, to garnish</p>],
#   'recipe_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2020/12/201106_059A_BaoBuns-1024x450.jpg',
#   'judge_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2019/08/Paul_Hollywood_395_2900x2900-1024x1024-100x100.png'},
#  {'title': 'Prue Leith’s Last-minute Christmas Pudding',
#   'judge': 'Prue Leith',
#   'makes': '8-10',
#   'difficulty': 'Easy',
#   'hands_on_time': '20 mins',
#   'baking_time': '40 mins',
#   'ingredients': [<p>150g raisins</p>,
#    <p>150g sultanas</p>,
#    <p>150g currants</p>,
#    <p>100g dried cranberries </p>,
#    <p>50g mixed peel </p>,
#    <p>Juice and finely grated zest of 1 large unwaxed orange</p>,
#    <p>100ml brandy</p>,
#    <p>75g molasses</p>,
#    <p>1 tsp bicarbonate of soda</p>,
#    <p>1 Bramley apple, peeled and grated (150g grated weight) </p>,
#    <p>140g frozen unsalted butter, grated</p>,
#    <p>175g dark muscovado sugar </p>,
#    <p>175g fresh white breadcrumbs</p>,
#    <p>140g self-raising flour</p>,
#    <p>1 tsp cinnamon</p>,
#    <p>1 tsp mixed spice</p>,
#    <p>2 large eggs, beaten</p>,
#    <p>1 candied clementine</p>,
#    <p>250ml whole milk</p>,
#    <p>250ml double cream</p>,
#    <p>6 large egg yolks</p>,
#    <p>65g caster sugar</p>,
#    <p>2 tbsp orange liqueur </p>],
#   'recipe_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2020/12/201104_055B_ChristmasPudding-1024x450.jpg',
#   'judge_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2019/08/Prue_Leith_441_2900x2900-1024x1024-100x100.png'},
#  {'title': 'Prue Leith’s Coffee Walnut Whirls',
#   'judge': 'Prue Leith',
#   'makes': '8',
#   'difficulty': 'Challenging',
#   'hands_on_time': '1 hr 40 mins, plus chilling',
#   'baking_time': '20 mins',
#   'ingredients': [<p>60g walnuts</p>,
#    <p>80g plain flour, plus extra for dusting </p>,
#    <p>⅛ tsp baking powder</p>,
#    <p>55g unsalted butter </p>,
#    <p>40g icing sugar </p>,
#    <p>1 egg yolk </p>,
#    <p>150ml double cream</p>,
#    <p>50g coffee beans</p>,
#    <p>250g milk chocolate, chopped </p>,
#    <p>2 gelatine leaves</p>,
#    <p>2 egg whites </p>,
#    <p>½ tsp cream of tartar </p>,
#    <p>75g caster sugar </p>,
#    <p>125g corn syrup</p>,
#    <p>1½ tsp vanilla paste</p>,
#    <p>300g 54% dark chocolate</p>,
#    <p>8 walnut halves</p>],
#   'recipe_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2020/11/201103_051B_WalnutWhips-1024x450.jpg',
#   'judge_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2019/08/Prue_Leith_441_2900x2900-1024x1024-100x100.png'},
#  {'title': 'Paul Hollywood’s Danish Cornucopia',
#   'judge': 'Paul Hollywood',
#   'makes': '10',
#   'difficulty': 'Challenging',
#   'hands_on_time': '2 hrs, plus chilling',
#   'baking_time': '12 mins',
#   'ingredients': [<p>250g ground almonds</p>,
#    <p>250g icing sugar, sifted, plus extra for dusting</p>,
#    <p>2 egg whites, lightly whisked</p>,
#    <p>½ tsp almond extract </p>,
#    <p>300g 54% dark chocolate, chopped </p>,
#    <p>1 large egg whites </p>,
#    <p>200g icing sugar, sifted</p>,
#    <p>250g caster sugar</p>],
#   'recipe_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2020/11/201103_049B_Cornucopia-1024x450.jpg',
#   'judge_image': 'https://thegreatbritishbakeoff.co.uk/wp-content/uploads/2019/08/Paul_Hollywood_395_2900x2900-1024x1024-100x100.png'}]

# %%
for j in range(2, 12):
#    browser.find_by_css('a.page-numbers.no-focus').first.click()
    link1 = 'https://thegreatbritishbakeoff.co.uk/recipes/all/page/'
    link2 = '/?filter%5Bcollection%5D=81&showFilter=false#038;showFilter=false'
#    browser.find_by_text('2').click()
    browser.links.find_by_href(link1+str(j)+link2).click()
#    browser.click_link_by_partial_href('page/[j]')
    page(browser)
# Out:
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# judge not found
# judge not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-8-e45fb5d77bce> in <module>
#       6     browser.links.find_by_href(link1+str(j)+link2).click()
#       7 #    browser.click_link_by_partial_href('page/[j]')
# ----> 8     page(browser)
#
# <ipython-input-6-193d3a7b3edf> in page(browser)
#      26                 except IndexError:
#      27                     print("not found")
# ---> 28                 difficulty = x1.find('span', class_='value').get_text()
#      29
#      30                 try:
#
# UnboundLocalError: local variable 'x1' referenced before assignment

# %%
technical_list_df = pd.DataFrame(technical_list)
technical_list_df
