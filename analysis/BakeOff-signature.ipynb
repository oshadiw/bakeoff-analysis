# %%
import pandas as pd
import numpy as np
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup

# %%
# Set the executable path and initialize the chrome browser in splinter

executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
url = 'https://thegreatbritishbakeoff.co.uk/recipes/all/?filter[collection]=80&showFilter=false'
browser.visit(url)
browser.links.find_by_partial_text('OK').click()

# %%
#Last page of the browser
last_url = browser.find_by_css('a.page-numbers')[-1].value
last_url
# Out:
# '11'

# %%
# Creating an empty list to store the titles, image, servings
signature_list=[]

# Creating an empty dictionary
signature_dict ={'title':[], 'judge':[], 'makes':[], 'difficulty':[], 'hands_on_time':[], 'baking_time':[], 'ingredients':[], 'recipe_image':[], 'judge_image':[]}

# %%
nRecipe = browser.find_by_css('div.recipes-loop__item.collection')

# %%
def page(browser):

    for i in range(len(nRecipe)):
                        
                # loading the page
                browser.find_by_css("div.recipes-loop__item.collection", wait_time=1)[i].click()
                recipe_html = browser.html
                recipe_soup = soup(recipe_html, 'html.parser')
                               
                title = recipe_soup.find('h1').text
                h5=recipe_soup.find('h5')
                
                global j0
                try:
                    j0 = recipe_soup.h5.find('a').text
                except AttributeError:
                    print("judge not found")                    
                judge = j0
                
                global x0
                try:
                    x0 = recipe_soup.find_all('div', class_='recipe-details__item')[0]
                except UnboundLocalError:
                    print("not found")
                except IndexError:
                    print("not found")
                makes = x0.find('span', class_='value').get_text()

                global x1
                try:
                    x1 = recipe_soup.find_all('div', class_='recipe-details__item')[1]
                except UnboundLocalError:
                    print("not found")
                except IndexError:
                    print("not found")
                difficulty = x1.find('span', class_='value').get_text()
    
                global x2
                try:
                    x2 = recipe_soup.find_all('div', class_='recipe-details__item')[2]
                except UnboundLocalError:
                    print("not found")
                except IndexError:
                    print("not found")
                hands_on_time = x2.find('span', class_='value').get_text()
                
                global x3
                try:
                    x3 = recipe_soup.find_all('div', class_='recipe-details__item')[3]
                except UnboundLocalError:
                    print("not found")
                except IndexError:
                    print("not found")                
                baking_time = x3.find('span', class_='value').get_text()
                
                try:
                    i0 = recipe_soup.find('div', class_='recipe-sidebar__section__content').findAll()
#                    i0 = recipe_soup.find('div', class_='recipe-sidebar__section recipe-sidebar__section--ingredients').findAll('p')
                except AttributeError:
                    print("not found")
                ingredients = i0


                container = recipe_soup.find('div', class_='container')               
                recipe_image = container.find_all('img')[0].get('src')
                
                global j1
                try:
                    j1 = container.find_all('img')[1].get('src')
                except UnboundLocalError:
                    print("not found")
                except IndexError:
                    print("judge not found")                
                judge_image = j1
                    


                # Creating dictionary keys
                signature_dict['title'].append(title)
                signature_dict['judge'].append(judge)
                signature_dict['makes'].append(makes)
                signature_dict['difficulty'].append(difficulty)
                signature_dict['hands_on_time'].append(hands_on_time)
                signature_dict['baking_time'].append(baking_time)
                signature_dict['ingredients'].append(ingredients)
                signature_dict['recipe_image'].append(recipe_image)
                signature_dict['judge_image'].append(judge_image)

                signature_dictionary = {'title':title, 'judge':judge, 'makes':makes, 'difficulty':difficulty, 'hands_on_time':hands_on_time, 'baking_time':baking_time, 'ingredients':ingredients, 'recipe_image':recipe_image, 'judge_image':judge_image}

                signature_list.append(signature_dictionary)

                browser.back()
    return signature_list

# %%
for j in range(1, int(last_url)+1):
    
    if j == 1:
        page(browser)
    else:
        link1 = 'https://thegreatbritishbakeoff.co.uk/recipes/all/page/'
        link2 = '/?filter%5Bcollection%5D=80&showFilter=false#038;showFilter=false'

        browser.links.find_by_href(link1+str(j)+link2).click()
        nRecipe = browser.find_by_css('div.recipes-loop__item.collection')

        page(browser)
# Out:
# judge not found
# judge not found
# judge not found
# not found
# not found
# not found
# judge not found
# judge not found
# not found
# not found
# not found
# judge not found

# %%
signature_df = pd.DataFrame(signature_list)

# %%
signature_df
# Out:
#                                                  title  judge     makes  \
# 0    Rahul’s Spiced Apple & Plum Nut Crumble with O...  Rahul         8
# 1    Nancy’s Caribbean Crumble with Lime-crusted Co...  Nancy         6
# 2            Rosie’s Date, Cranberry & Mace Panettones  Rosie         6
# 3     Ruby’s Boozy Chai, Cherry & Chocolate Panettones   Ruby     16-18
# 4                  Dave’s Caramel Latte Custard Slices   Dave         8
# ..                                                 ...    ...       ...
# 122          Liam’s Apple, Almond & Maple Crumble Loaf   Liam     10–12
# 123                               Peter’s Coconut Cake  Peter        12
# 124                  Tom’s Gilded Pear & Cardamom Cake    Tom        16
# 125                        Walnut & Stilton Soda Bread    Tom  2 loaves
# 126                          Zingy Citrus Madeira Cake    Tom         8
#
#       difficulty         hands_on_time   baking_time  \
# 0    Needs skill  2 hrs, plus freezing       35 mins
# 1           Easy                  1 hr       30 mins
# 2    Needs skill                 2 hrs       45 mins
# 3    Needs skill     1 hr, plus rising       25 mins
# 4    Needs skill          1 hr 30 mins       35 mins
# ..           ...                   ...           ...
# 122         Easy               30 mins  1 hr 20 mins
# 123         Easy               40 mins       50 mins
# 124         Easy                  1 hr       55 mins
# 125         Easy                  1 hr       55 mins
# 126         Easy                  1 hr       55 mins
#
#                                            ingredients  \
# 0    [[For the ice cream:], l whole milk], [2 ...
# 1    [[For the coconut ice cream:], [2 large egg yo...
# 2    [[For the panettone dough:], [410g extra-stron...
# 3    [[For the soaked fruits:], l almond lique...
# 4    [[For the rough puff pastry:], [280g plain flo...
# ..                                                 ...
# 122  [[For the sponge:], [1 Bramley apple (about 32...
# 123  [[For the sponge:], [1 whole fresh coconut], [...
# 124  [[For the sponge:], [6 pears, peeled, cored an...
# 125  [[200g Stilton], [150g walnut pieces], [100g s...
# 126  [[For the cake mixture:], [150g unsalted butte...
#
#                                           recipe_image  \
# 0    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 1    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 2    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 3    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 4    https://thegreatbritishbakeoff.co.uk/wp-conten...
# ..                                                 ...
# 122  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 123  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 124  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 125  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 126  https://thegreatbritishbakeoff.co.uk/wp-conten...
#
#                                            judge_image
# 0    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 1    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 2    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 3    https://thegreatbritishbakeoff.co.uk/wp-conten...
# 4    https://thegreatbritishbakeoff.co.uk/wp-conten...
# ..                                                 ...
# 122  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 123  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 124  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 125  https://thegreatbritishbakeoff.co.uk/wp-conten...
# 126  https://thegreatbritishbakeoff.co.uk/wp-conten...
#
# [127 rows x 9 columns]

# %%
signature_df.to_csv('signature_list.csv', encoding='utf-8-sig', index=False)
